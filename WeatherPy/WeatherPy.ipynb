# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key


# Defininig Farenheit as units used in this project
units = "Imperial"


# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
#cities

base_url= "http://api.openweathermap.org/data/2.5/weather?"
units = "Imperial"
query_url = f"{base_url}appid={weather_api_key}&units={units}"
#query_url

print(len(cities))
cities
# Out:
# 615
# ['thompson',
#  'kapaa',
#  'ilulissat',
#  'puerto ayora',
#  'georgetown',
#  'burnie',
#  'tuatapere',
#  'rikitea',
#  'kungurtug',
#  'butaritari',
#  'shakawe',
#  'carire',
#  'bredasdorp',
#  'ushuaia',
#  'komsomolskiy',
#  'lipetsk',
#  'busselton',
#  'port alfred',
#  'barentsburg',
#  'hermanus',
#  'chagda',
#  'atuona',
#  'illoqqortoormiut',
#  'ken caryl',
#  'saldanha',
#  'yellowknife',
#  'vaini',
#  'mar del plata',
#  'pietarsaari',
#  'sarankhola',
#  'khatanga',
#  'sola',
#  'hilo',
#  'sunbury',
#  'bluff',
#  'adrar',
#  'mahebourg',
#  'nikolskoye',
#  'manokwari',
#  'tasiilaq',
#  'sitka',
#  'albany',
#  'mataura',
#  'aklavik',
#  'crab hill',
#  'hun',
#  'la seyne-sur-mer',
#  'hobart',
#  'anito',
#  'saint-philippe',
#  'arraial do cabo',
#  'arman',
#  'gravelbourg',
#  'griffith',
#  'bengkulu',
#  'cherskiy',
#  'inirida',
#  'tara',
#  'lorengau',
#  'ixtapa',
#  'qaqortoq',
#  'aden',
#  'matagami',
#  'naze',
#  'longyearbyen',
#  'mutare',
#  'port elizabeth',
#  'pangnirtung',
#  'huty',
#  'dikson',
#  'severo-kurilsk',
#  'areosa',
#  'saskylakh',
#  'nishihara',
#  'vestmannaeyjar',
#  'achinsk',
#  'esperance',
#  'hidalgo',
#  'evensk',
#  'tual',
#  'jamestown',
#  'fortuna',
#  'hithadhoo',
#  'ust-shonosha',
#  'kidal',
#  'talnakh',
#  'cape town',
#  'sao filipe',
#  'punta arenas',
#  'kalomo',
#  'hamilton',
#  'dunmore town',
#  'cabo san lucas',
#  'kruisfontein',
#  'koungou',
#  'bambous virieux',
#  'dolinsk',
#  'isangel',
#  'barrow',
#  'saint anthony',
#  'kupang',
#  'lompoc',
#  'castro',
#  'fernie',
#  'champerico',
#  'sao jose da coroa grande',
#  'vaitupu',
#  'hasaki',
#  'sisimiut',
#  'touros',
#  'naftah',
#  'poya',
#  'qaanaaq',
#  'kokkola',
#  'los llanos de aridane',
#  'port-gentil',
#  'chulym',
#  'constitucion',
#  'taoudenni',
#  'finschhafen',
#  'richards bay',
#  'husavik',
#  'tiksi',
#  'airai',
#  'khon buri',
#  'sumbawa',
#  'amderma',
#  'macas',
#  'belushya guba',
#  'avarua',
#  'gorin',
#  'peterhead',
#  'provideniya',
#  'wajir',
#  'riwaka',
#  'alugan',
#  'fevralsk',
#  'alice springs',
#  'faanui',
#  'ostrovnoy',
#  'tsihombe',
#  'khuzhir',
#  'gumushane',
#  'carballo',
#  'namibe',
#  'bethel',
#  'coihueco',
#  'lac du bonnet',
#  'ulaangom',
#  'zhigansk',
#  'meulaboh',
#  'miracema do tocantins',
#  'morgan city',
#  'vila franca do campo',
#  'clyde river',
#  'beloha',
#  'lebu',
#  'tukrah',
#  'asau',
#  'lata',
#  'hibbing',
#  'saint-francois',
#  'pervomayskoye',
#  'arkhangelsk',
#  'vestmanna',
#  'morros',
#  'vung tau',
#  'mutis',
#  'hualmay',
#  'villarrica',
#  'half moon bay',
#  'rock sound',
#  'souillac',
#  'ponta do sol',
#  'new norfolk',
#  'chulumani',
#  'puerto leguizamo',
#  'pingliang',
#  'candolim',
#  'mount isa',
#  'tateyama',
#  'kalaleh',
#  'north bend',
#  'botwood',
#  'nizhnyaya poyma',
#  'westport',
#  'maniitsoq',
#  'carnarvon',
#  'gamba',
#  'merrill',
#  'yar-sale',
#  'chuy',
#  'bilibino',
#  'tabulbah',
#  'cidreira',
#  'ville-marie',
#  'marcona',
#  'tigil',
#  'buraydah',
#  'coihaique',
#  'dire',
#  'nuuk',
#  'toftir',
#  'bondo',
#  'bahia honda',
#  'llanes',
#  'salalah',
#  'grindavik',
#  'rocha',
#  'talara',
#  'lucera',
#  'kendari',
#  'taolanaro',
#  'genhe',
#  'samusu',
#  'houma',
#  'koson',
#  'salcininkai',
#  'luderitz',
#  'tuktoyaktuk',
#  'general roca',
#  'san carlos del zulia',
#  'bathsheba',
#  'gallup',
#  'norman wells',
#  'eersel',
#  'attawapiskat',
#  'panguipulli',
#  'vihari',
#  'lavrentiya',
#  'karakendzha',
#  'ayagoz',
#  'qafsah',
#  'beruni',
#  'sentyabrskiy',
#  'atar',
#  'lengshuitan',
#  'torbay',
#  'east london',
#  'sakaiminato',
#  'branford',
#  'policoro',
#  'kahului',
#  'saurimo',
#  'guayaramerin',
#  'vardo',
#  'college',
#  'banjar',
#  'upernavik',
#  'beyneu',
#  'parana',
#  'wawa',
#  'viedma',
#  'xingyi',
#  'vao',
#  'armacao de pera',
#  'alexandria',
#  'thinadhoo',
#  'vila',
#  'victoria',
#  'kautokeino',
#  'berlevag',
#  'pasni',
#  'price',
#  'lithakia',
#  'saint stephen',
#  'bargal',
#  'amapa',
#  'ladario',
#  'rio gallegos',
#  'madang',
#  'rawson',
#  'yemelyanovo',
#  'sioux lookout',
#  'fayaoue',
#  'port lincoln',
#  'ribeira grande',
#  'khandyga',
#  'navoloki',
#  'halalo',
#  'panacan',
#  'ternate',
#  'guerrero negro',
#  'avera',
#  'vanimo',
#  'manzhouli',
#  'lodja',
#  'banepa',
#  'manono',
#  'paramirim',
#  'chernyshevsk',
#  'kaitangata',
#  'sechura',
#  'itupiranga',
#  'emborion',
#  'ancud',
#  'ngukurr',
#  'moussoro',
#  'aswan',
#  'kieta',
#  'cuauhtemoc',
#  'kadykchan',
#  'iqaluit',
#  'medeiros neto',
#  'luyang',
#  'sabang',
#  'mys shmidta',
#  'puerto narino',
#  'shingu',
#  'geraldton',
#  'ampanihy',
#  'leningradskiy',
#  'ryotsu',
#  'saint george',
#  'sinnamary',
#  'belmonte',
#  'basco',
#  'taltal',
#  'zlitan',
#  'palu',
#  'tessalit',
#  'zilair',
#  'kodiak',
#  'quelimane',
#  'wanning',
#  'surab',
#  'chokurdakh',
#  'farmington',
#  'nantucket',
#  'penzance',
#  'port hardy',
#  'tansen',
#  'waingapu',
#  'porto novo',
#  'kimbe',
#  'shimanovsk',
#  'powell',
#  'celestun',
#  'ocampo',
#  'chimbote',
#  'abu dhabi',
#  'portland',
#  'ures',
#  'inhambane',
#  'burica',
#  'tahta',
#  'mezapa',
#  'koumac',
#  'kushiro',
#  'aripuana',
#  'warqla',
#  'kirksville',
#  'gornji vakuf',
#  'teguise',
#  'mendahara',
#  'kazerun',
#  'porto belo',
#  'mareeba',
#  'santa cruz de tenerife',
#  'lasa',
#  'altus',
#  'cockburn town',
#  'sandwick',
#  'padang',
#  'yelizovo',
#  'kavieng',
#  'cabedelo',
#  'seguela',
#  'olenino',
#  'tanout',
#  'lucapa',
#  'kedrovyy',
#  'honningsvag',
#  'charkhi dadri',
#  'saleaula',
#  'abu kamal',
#  'kambove',
#  'eydhafushi',
#  'codrington',
#  'zarubino',
#  'broome',
#  'umm lajj',
#  'jining',
#  'dronninglund',
#  'poum',
#  'warmbad',
#  'eenhana',
#  'teya',
#  'port hedland',
#  'lohr',
#  'santa cruz',
#  'kavaratti',
#  'svetlaya',
#  'hameenlinna',
#  'bundaberg',
#  'laguna',
#  'chama',
#  'kenitra',
#  'tarakan',
#  'iskateley',
#  'sumkino',
#  'bonavista',
#  'sakakah',
#  'carutapera',
#  'visnes',
#  'faya',
#  'vammala',
#  'grand river south east',
#  'maksi',
#  'sorland',
#  'mandalgovi',
#  'zhenjiang',
#  'caravelas',
#  'bolungarvik',
#  'luan',
#  'pisco',
#  'coquimbo',
#  'zavyalovo',
#  'amasia',
#  'katsuura',
#  'haines junction',
#  'havre',
#  'palmer',
#  'bagdarin',
#  'narsaq',
#  'korla',
#  'karauzyak',
#  'nanding',
#  'praya',
#  'coruripe',
#  'umzimvubu',
#  'ambodifototra',
#  'saint-pierre',
#  'kununurra',
#  'manadhoo',
#  'todos santos',
#  'klaksvik',
#  'mezen',
#  'cairns',
#  'kismayo',
#  'atsiki',
#  'ballina',
#  'kalmunai',
#  'dolbeau',
#  'leshukonskoye',
#  'serowe',
#  'mstera',
#  'nyurba',
#  'fort nelson',
#  'erzin',
#  'rincon',
#  'katsiveli',
#  'kemijarvi',
#  'terrace',
#  'kainantu',
#  'papa',
#  'nouadhibou',
#  'tabou',
#  'muros',
#  'jiangyou',
#  'nicoya',
#  'garoua boulai',
#  'sur',
#  'yining',
#  'bay roberts',
#  'say',
#  'cayenne',
#  'mayumba',
#  'tocopilla',
#  'ishigaki',
#  'egvekinot',
#  'abonnema',
#  'kitui',
#  'maltahohe',
#  'swift current',
#  'jiexiu',
#  'beira',
#  'biu',
#  'dolores',
#  'nizhniy odes',
#  'bodden town',
#  'karratha',
#  'paratinga',
#  'udachnyy',
#  'port macquarie',
#  'thiruvananthapuram',
#  'tabas',
#  'antanifotsy',
#  'ugento',
#  'marawi',
#  'boa vista',
#  'araouane',
#  'mersing',
#  'yatou',
#  'donduseni',
#  'zhizdra',
#  'clifton',
#  'antofagasta',
#  'yulara',
#  'san policarpo',
#  'balkhash',
#  'mutsamudu',
#  'luganville',
#  'borogontsy',
#  'kenai',
#  'nizhneyansk',
#  'umm kaddadah',
#  'maba',
#  'tuyen quang',
#  'dafeng',
#  'egersund',
#  'luanda',
#  'wolbrom',
#  'wageningen',
#  'san patricio',
#  'temaraia',
#  'moose factory',
#  'roswell',
#  'garowe',
#  'bowling green',
#  'bayevo',
#  'nunchia',
#  'almas',
#  'marsh harbour',
#  'bintulu',
#  'geilo',
#  'beringovskiy',
#  'el alto',
#  'dickinson',
#  'port hawkesbury',
#  'lazaro cardenas',
#  'izhevsk',
#  'sangerhausen',
#  'kazachinskoye',
#  'dryden',
#  'buluang',
#  'la orilla',
#  'makat',
#  'paamiut',
#  'mitu',
#  'upata',
#  'mangulile',
#  'sistranda',
#  'gohpur',
#  'liberal',
#  'narva-joesuu',
#  'makokou',
#  'bristol',
#  'coahuayana',
#  'camp verde',
#  'flinders',
#  'maxixe',
#  'barroui',
#  'oranjemund',
#  'nome',
#  'ahipara',
#  'rungata',
#  'birjand',
#  'kitimat',
#  'lavras da mangabeira',
#  'deh rawud',
#  'nanortalik',
#  'kivertsi',
#  'foki',
#  'aksha',
#  'dudinka',
#  'cabatuan',
#  'goure',
#  'chivacoa',
#  'rivadavia',
#  'mehamn',
#  'shimoda',
#  'le port',
#  'coari',
#  'nepomuk',
#  'kyra',
#  'sergiyevsk',
#  'norden',
#  'iberia',
#  'banda aceh',
#  'petropavlovsk-kamchatskiy',
#  'daru',
#  'nenjiang',
#  'sao gabriel da cachoeira',
#  'astana',
#  'mon',
#  'karonga',
#  'yakeshi',
#  'surt',
#  'mariental',
#  'terney',
#  'kaeo',
#  'santa fe',
#  'baculin',
#  'aquiraz',
#  'tabiauea',
#  'thanh hoa',
#  'hitoyoshi',
#  'marmarion',
#  'sulangan',
#  'vallenar',
#  'klamath falls',
#  'dunedin',
#  'shilka',
#  'qandahar',
#  'bonga',
#  'zalegoshch',
#  'duldurga',
#  'the valley',
#  'kyabe',
#  'bababe',
#  'louisbourg',
#  'sembakung',
#  'nylstroom',
#  'adela']

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
city_name_data = []
lat_list = []
lng_list = []
max_temp = []
humidity = []
cloudiness = []
wind_speed = []
country = []
date = []



print("Beginning Data Retrieval")
print("-----------------------------")



for city in cities:
    try:
        response = requests.get(f"{query_url}&q={city}").json()
        city_name_data.append(response["name"])
        lat_list.append(response["coord"]["lat"])
        lng_list.append(response["coord"]["lat"])
        max_temp.append(response["main"]["temp_max"])
        humidity.append(response["main"]["humidity"])
        cloudiness.append(response["clouds"]["all"])
        wind_speed.append(response["wind"]["speed"])
        country.append(response["sys"]["country"])
        date.append(response["dt"])
        city_print=response["name"]
        print(f"Processing Record | {city_print}")
    except:
        print("No results, skipping.....")
    continue
    
print("-----------------------------")
print("Data Retrieval Complete")      
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record | Thompson
# Processing Record | Kapaa
# Processing Record | Ilulissat
# Processing Record | Puerto Ayora
# Processing Record | George Town
# Processing Record | Burnie
# Processing Record | Tuatapere
# Processing Record | Rikitea
# Processing Record | Kungurtug
# Processing Record | Butaritari
# Processing Record | Shakawe
# Processing Record | Cariré
# Processing Record | Bredasdorp
# Processing Record | Ushuaia
# Processing Record | Yangi Marg`ilon
# Processing Record | Lipetsk
# Processing Record | Busselton
# Processing Record | Port Alfred
# No results, skipping.....
# Processing Record | Hermanus
# No results, skipping.....
# Processing Record | Atuona
# No results, skipping.....
# Processing Record | Ken Caryl
# Processing Record | Saldanha
# Processing Record | Yellowknife
# Processing Record | Vaini
# Processing Record | Mar del Plata
# Processing Record | Pedersore
# Processing Record | Sarankhola
# Processing Record | Khatanga
# Processing Record | Sola
# Processing Record | Hilo
# Processing Record | Sunbury
# Processing Record | Bluff
# Processing Record | Adrar
# Processing Record | Mahébourg
# Processing Record | Nikolskoye
# Processing Record | Manokwari
# Processing Record | Tasiilaq
# Processing Record | Sitka
# Processing Record | Albany
# Processing Record | Mataura
# Processing Record | Aklavik
# No results, skipping.....
# Processing Record | Hūn
# Processing Record | La Seyne-sur-Mer
# Processing Record | Hobart
# Processing Record | Anito
# Processing Record | Saint-Philippe
# Processing Record | Arraial do Cabo
# Processing Record | Arman'
# Processing Record | Gravelbourg
# Processing Record | Griffith
# Processing Record | Bengkulu
# Processing Record | Cherskiy
# Processing Record | Inírida
# Processing Record | Tara
# Processing Record | Lorengau
# Processing Record | Ixtapa
# Processing Record | Qaqortoq
# Processing Record | Aden
# Processing Record | Matagami
# Processing Record | Naze
# Processing Record | Longyearbyen
# Processing Record | Mutare
# Processing Record | Port Elizabeth
# Processing Record | Pangnirtung
# Processing Record | Huty
# Processing Record | Dikson
# Processing Record | Severo-Kuril'sk
# Processing Record | Areosa
# Processing Record | Saskylakh
# Processing Record | Nishihara
# Processing Record | Vestmannaeyjar
# Processing Record | Achinsk
# Processing Record | Esperance
# Processing Record | Hidalgo
# Processing Record | Evensk
# Processing Record | Tual
# Processing Record | Jamestown
# Processing Record | Fortuna
# Processing Record | Hithadhoo
# Processing Record | Ust'-Shonosha
# Processing Record | Kidal
# Processing Record | Talnakh
# Processing Record | Cape Town
# Processing Record | São Filipe
# Processing Record | Punta Arenas
# No results, skipping.....
# Processing Record | Hamilton
# Processing Record | Dunmore Town
# Processing Record | Cabo San Lucas
# Processing Record | Kruisfontein
# Processing Record | Koungou
# Processing Record | Bambous Virieux
# Processing Record | Dolinsk
# Processing Record | Isangel
# Processing Record | Barrow
# Processing Record | Saint Anthony
# Processing Record | Kupang
# Processing Record | Lompoc
# Processing Record | Castro
# Processing Record | Fernie
# Processing Record | Champerico
# Processing Record | São José da Coroa Grande
# No results, skipping.....
# Processing Record | Hasaki
# Processing Record | Sisimiut
# Processing Record | Touros
# No results, skipping.....
# Processing Record | Poya
# Processing Record | Qaanaaq
# Processing Record | Kokkola
# Processing Record | Los Llanos de Aridane
# Processing Record | Port-Gentil
# Processing Record | Chulym
# Processing Record | Constitución
# Processing Record | Taoudenni
# Processing Record | Finschhafen
# Processing Record | Richards Bay
# Processing Record | Husavik
# Processing Record | Tiksi
# Processing Record | Airai
# Processing Record | Khon Buri
# No results, skipping.....
# No results, skipping.....
# Processing Record | Macas
# No results, skipping.....
# Processing Record | Avarua
# Processing Record | Gorin
# Processing Record | Peterhead
# Processing Record | Provideniya
# Processing Record | Wajir
# Processing Record | Riwaka
# Processing Record | Alugan
# No results, skipping.....
# Processing Record | Alice Springs
# Processing Record | Faanui
# Processing Record | Ostrovnoy
# No results, skipping.....
# Processing Record | Khuzhir
# No results, skipping.....
# Processing Record | Carballo
# Processing Record | Mossamedes
# Processing Record | Bethel
# Processing Record | Coihueco
# Processing Record | Lac du Bonnet
# Processing Record | Ulaangom
# Processing Record | Zhigansk
# Processing Record | Meulaboh
# Processing Record | Miracema do Tocantins
# Processing Record | Morgan City
# Processing Record | Vila Franca do Campo
# Processing Record | Clyde River
# Processing Record | Beloha
# Processing Record | Lebu
# Processing Record | Tūkrah
# Processing Record | Asău
# Processing Record | Lata
# Processing Record | Hibbing
# Processing Record | Saint-François
# Processing Record | Pervomayskoye
# Processing Record | Arkhangelsk
# Processing Record | Vestmanna
# Processing Record | Morros
# Processing Record | Vung Tau
# Processing Record | Bahía Solano
# Processing Record | Hualmay
# Processing Record | Villarrica
# Processing Record | Half Moon Bay
# Processing Record | Rock Sound
# Processing Record | Souillac
# Processing Record | Ponta do Sol
# Processing Record | New Norfolk
# Processing Record | Chulumani
# Processing Record | Caucayá
# Processing Record | Pingliang
# Processing Record | Candolim
# Processing Record | Mount Isa
# Processing Record | Tateyama
# Processing Record | Kalāleh
# Processing Record | North Bend
# Processing Record | Botwood
# Processing Record | Nizhnyaya Poyma
# Processing Record | Westport
# Processing Record | Maniitsoq
# Processing Record | Carnarvon
# Processing Record | Gamba
# Processing Record | Merrill
# Processing Record | Yar-Sale
# Processing Record | Chui
# Processing Record | Bilibino
# No results, skipping.....
# Processing Record | Cidreira
# Processing Record | Ville-Marie
# No results, skipping.....
# Processing Record | Tigil'
# Processing Record | Buraidah
# Processing Record | Coyhaique
# Processing Record | Diré
# Processing Record | Nuuk
# No results, skipping.....
# Processing Record | Bondo
# Processing Record | Bahía Honda
# Processing Record | Llanes
# Processing Record | Salalah
# Processing Record | Grindavik
# Processing Record | Rocha
# Processing Record | Talara
# Processing Record | Lucera
# Processing Record | Kendari
# No results, skipping.....
# Processing Record | Genhe
# No results, skipping.....
# Processing Record | Houma
# Processing Record | Koson
# Processing Record | Šalčininkai
# Processing Record | Lüderitz
# Processing Record | Tuktoyaktuk
# Processing Record | General Roca
# Processing Record | San Carlos del Zulia
# Processing Record | Bathsheba
# Processing Record | Gallup
# Processing Record | Norman Wells
# Processing Record | Eersel
# No results, skipping.....
# Processing Record | Panguipulli
# Processing Record | Vehari
# Processing Record | Lavrentiya
# No results, skipping.....
# Processing Record | Ayagoz
# No results, skipping.....
# No results, skipping.....
# No results, skipping.....
# Processing Record | Atar
# Processing Record | Lengshuitan
# Processing Record | Torbay
# Processing Record | East London
# Processing Record | Sakaiminato
# Processing Record | Branford
# Processing Record | Policoro
# Processing Record | Kahului
# Processing Record | Saurimo
# Processing Record | Guayaramerín
# Processing Record | Vardø
# Processing Record | College
# Processing Record | Banjar
# Processing Record | Upernavik
# Processing Record | Beyneu
# Processing Record | Paraná
# Processing Record | Wawa
# Processing Record | Viedma
# Processing Record | Xingyi
# Processing Record | Vao
# Processing Record | Armação de Pêra
# Processing Record | Alexandria
# Processing Record | Thinadhoo
# Processing Record | Vila
# Processing Record | Hong Kong
# Processing Record | Kautokeino
# Processing Record | Berlevåg
# Processing Record | Pasni
# Processing Record | Price
# Processing Record | Lithakia
# Processing Record | Saint Stephen
# No results, skipping.....
# Processing Record | Amapá
# Processing Record | Ladário
# Processing Record | Río Gallegos
# Processing Record | Madang
# Processing Record | Rawson
# Processing Record | Yemel'yanovo
# Processing Record | Sioux Lookout
# Processing Record | Fayaoué
# Processing Record | Port Lincoln
# Processing Record | Ribeira Grande
# Processing Record | Khandyga
# Processing Record | Navoloki
# No results, skipping.....
# Processing Record | Panacan
# Processing Record | Ternate
# Processing Record | Guerrero Negro
# Processing Record | Avera
# Processing Record | Vanimo
# Processing Record | Manzhouli
# Processing Record | Lodja
# Processing Record | Banepā
# Processing Record | Manono
# Processing Record | Paramirim
# Processing Record | Chernyshevsk
# Processing Record | Kaitangata
# Processing Record | Sechura
# Processing Record | Itupiranga
# Processing Record | Empório
# Processing Record | Ancud
# No results, skipping.....
# Processing Record | Moussoro
# Processing Record | Aswān
# Processing Record | Kieta
# Processing Record | Cuauhtémoc
# No results, skipping.....
# Processing Record | Iqaluit
# Processing Record | Medeiros Neto
# Processing Record | Luyang
# Processing Record | Sabang
# No results, skipping.....
# Processing Record | Puerto Nariño
# Processing Record | Shingū
# Processing Record | Geraldton
# Processing Record | Ampanihy
# Processing Record | Leningradskiy
# Processing Record | Ryōtsu-minato
# Processing Record | Saint George
# Processing Record | Sinnamary
# Processing Record | Belmonte
# Processing Record | Basco
# Processing Record | Taltal
# Processing Record | Zliten
# Processing Record | Palu
# Processing Record | Tessalit
# Processing Record | Zilair
# Processing Record | Saint Paul Harbor
# Processing Record | Quelimane
# Processing Record | Wanning
# Processing Record | Surab
# Processing Record | Chokurdakh
# Processing Record | Farmington
# Processing Record | Nantucket
# Processing Record | Penzance
# Processing Record | Port Hardy
# Processing Record | Tānsen
# Processing Record | Waingapu
# Processing Record | Porto-Novo
# Processing Record | Kimbe
# Processing Record | Shimanovsk
# Processing Record | Powell
# Processing Record | Celestún
# Processing Record | Ocampo
# Processing Record | Chimbote
# Processing Record | Abu Dhabi
# Processing Record | Portland
# Processing Record | Ures
# Processing Record | Inhambane
# No results, skipping.....
# Processing Record | Ţahţā
# Processing Record | Mezapa
# Processing Record | Koumac
# Processing Record | Kushiro
# Processing Record | Aripuanã
# No results, skipping.....
# Processing Record | Kirksville
# Processing Record | Gornji Vakuf
# Processing Record | Teguise
# No results, skipping.....
# Processing Record | Kāzerūn
# Processing Record | Porto Belo
# Processing Record | Mareeba
# Processing Record | Santa Cruz de Tenerife
# Processing Record | Laas
# Processing Record | Altus
# Processing Record | Cockburn Town
# Processing Record | Sandwick
# Processing Record | Padang
# Processing Record | Yelizovo
# Processing Record | Kavieng
# Processing Record | Cabedelo
# Processing Record | Séguéla
# Processing Record | Olenino
# Processing Record | Tanout
# Processing Record | Lucapa
# Processing Record | Kedrovyy
# Processing Record | Honningsvåg
# Processing Record | Charkhi Dādri
# No results, skipping.....
# Processing Record | Abu Kamal
# Processing Record | Kambove
# Processing Record | Eydhafushi
# Processing Record | Codrington
# Processing Record | Zarubino
# Processing Record | Broome
# Processing Record | Umluj
# Processing Record | Jining
# Processing Record | Dronninglund
# Processing Record | Poum
# Processing Record | Warmbad
# Processing Record | Eenhana
# Processing Record | Teya
# Processing Record | Port Hedland
# Processing Record | Lohr a. Main
# Processing Record | Santa Cruz de la Sierra
# Processing Record | Kavaratti
# Processing Record | Svetlaya
# Processing Record | Hämeenlinna
# Processing Record | Bundaberg
# Processing Record | Laguna
# Processing Record | Cham
# Processing Record | Kenitra
# Processing Record | Tarakan
# Processing Record | Iskateley
# Processing Record | Sumkino
# Processing Record | Bonavista
# Processing Record | Sakakah
# Processing Record | Carutapera
# Processing Record | Visnes
# Processing Record | Faya
# Processing Record | Vammala
# No results, skipping.....
# Processing Record | Maksi
# Processing Record | Sørland
# Processing Record | Mandalgovi
# Processing Record | Zhenjiang
# Processing Record | Caravelas
# No results, skipping.....
# Processing Record | Luan
# Processing Record | Pisco
# Processing Record | Coquimbo
# Processing Record | Zavyalovo
# Processing Record | Amasya
# Processing Record | Katsuura
# Processing Record | Haines Junction
# Processing Record | Arrondissement du Havre
# Processing Record | Palmer
# Processing Record | Bagdarin
# Processing Record | Narsaq
# Processing Record | Korla
# No results, skipping.....
# Processing Record | Nanding
# Processing Record | Praia
# Processing Record | Coruripe
# No results, skipping.....
# No results, skipping.....
# Processing Record | Saint-Pierre
# Processing Record | Kununurra
# Processing Record | Manadhoo
# Processing Record | Todos Santos
# Processing Record | Klaksvík
# Processing Record | Mezen'
# Processing Record | Cairns
# Processing Record | Kismayo
# No results, skipping.....
# Processing Record | Ballina
# Processing Record | Kalmunai
# No results, skipping.....
# Processing Record | Leshukonskoye
# Processing Record | Serowe
# Processing Record | Mstera
# Processing Record | Nyurba
# Processing Record | Fort Nelson
# Processing Record | Erzin
# Processing Record | Rincon
# No results, skipping.....
# Processing Record | Kemijärvi
# Processing Record | Terrace
# Processing Record | Kainantu
# Processing Record | Pápa
# Processing Record | Nouadhibou
# Processing Record | Tabou
# Processing Record | Muros
# Processing Record | Jiangyou
# Processing Record | Nicoya
# Processing Record | Garoua Boulaï
# Processing Record | Sur
# Processing Record | Yining
# Processing Record | Bay Roberts
# Processing Record | Say
# Processing Record | Cayenne
# Processing Record | Mayumba
# Processing Record | Tocopilla
# Processing Record | Ishigaki
# Processing Record | Egvekinot
# Processing Record | Abonnema
# Processing Record | Kitui
# Processing Record | Maltahöhe
# Processing Record | Swift Current
# Processing Record | Jiexiu
# Processing Record | Beira
# Processing Record | Biu
# Processing Record | Dolores
# Processing Record | Nizhniy Odes
# Processing Record | Bodden Town
# Processing Record | Karratha
# Processing Record | Paratinga
# Processing Record | Udachny
# Processing Record | Port Macquarie
# Processing Record | Trivandrum
# Processing Record | Tabas
# Processing Record | Antanifotsy
# Processing Record | Ugento
# Processing Record | Marawi
# Processing Record | Boa Vista
# Processing Record | Araouane
# Processing Record | Mersing
# Processing Record | Yatou
# Processing Record | Donduşeni
# Processing Record | Zhizdra
# Processing Record | Clifton
# Processing Record | Antofagasta
# Processing Record | Yulara
# Processing Record | San Policarpo
# Processing Record | Balkhash
# No results, skipping.....
# Processing Record | Luganville
# Processing Record | Borogontsy
# Processing Record | Kenai
# No results, skipping.....
# Processing Record | Umm Kaddadah
# Processing Record | Maba
# Processing Record | Tuyen Quang
# Processing Record | Dafeng
# Processing Record | Egersund
# Processing Record | Luanda
# Processing Record | Wolbrom
# Processing Record | Gemeente Wageningen
# Processing Record | San Patricio
# No results, skipping.....
# Processing Record | Moose Factory
# Processing Record | Roswell
# Processing Record | Garoowe
# Processing Record | Bowling Green
# Processing Record | Bayevo
# Processing Record | Nunchía
# Processing Record | Almaş
# Processing Record | Marsh Harbour
# Processing Record | Bintulu
# Processing Record | Geilo
# Processing Record | Beringovskiy
# Processing Record | El Alto
# Processing Record | Dickinson
# Processing Record | Port Hawkesbury
# Processing Record | Lázaro Cárdenas
# Processing Record | Izhevsk
# Processing Record | Sangerhausen
# Processing Record | Kazachinskoye
# Processing Record | Dryden
# Processing Record | Buluang
# Processing Record | La Orilla
# Processing Record | Makat
# Processing Record | Paamiut
# Processing Record | Mitú
# Processing Record | Upata
# Processing Record | Mangulile
# Processing Record | Sistranda
# Processing Record | Gohpur
# Processing Record | Liberal
# Processing Record | Narva-Jõesuu
# Processing Record | Makokou
# Processing Record | Bristol
# Processing Record | Coahuayana Viejo
# Processing Record | Camp Verde
# Processing Record | Flinders
# Processing Record | Maxixe
# No results, skipping.....
# Processing Record | Oranjemund
# Processing Record | Nome
# Processing Record | Ahipara
# No results, skipping.....
# Processing Record | Birjand
# Processing Record | Kitimat
# Processing Record | Lavras da Mangabeira
# No results, skipping.....
# Processing Record | Nanortalik
# Processing Record | Kivertsi
# Processing Record | Foki
# Processing Record | Aksha
# Processing Record | Dudinka
# Processing Record | Cabatuan
# Processing Record | Gouré
# Processing Record | Chivacoa
# Processing Record | Rivadavia
# Processing Record | Mehamn
# Processing Record | Shimoda
# Processing Record | Le Port
# Processing Record | Coari
# Processing Record | Nepomuk
# Processing Record | Kyra
# Processing Record | Sergiyevsk
# Processing Record | Norden
# Processing Record | Iberia
# Processing Record | Banda Aceh
# Processing Record | Petropavlovsk-Kamchatskiy
# Processing Record | Daru
# Processing Record | Mergen
# Processing Record | São Gabriel da Cachoeira
# Processing Record | Nur-Sultan
# Processing Record | Mon
# Processing Record | Karonga
# Processing Record | Yakeshi
# Processing Record | Sirte
# Processing Record | Mariental
# Processing Record | Terney
# Processing Record | Kaeo
# Processing Record | Santa Fe
# Processing Record | Baculin
# Processing Record | Aquiraz
# No results, skipping.....
# Processing Record | Thanh Hoa
# Processing Record | Hitoyoshi
# Processing Record | Marmari
# Processing Record | Sulangan
# Processing Record | Vallenar
# Processing Record | Klamath Falls
# Processing Record | Dunedin
# Processing Record | Shilka
# No results, skipping.....
# Processing Record | Bonga
# Processing Record | Zalegoshch'
# Processing Record | Dul'durga
# Processing Record | The Valley
# Processing Record | Kyabé
# No results, skipping.....
# No results, skipping.....
# Processing Record | Sembakung
# No results, skipping.....
# Processing Record | Adela

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weatherdata_df = pd.DataFrame({"City":city_print, 
                               "Lat": lat_list,
                               "Lng": lng_list,
                               "Max Temp": max_temp,
                               "Humidity": humidity,
                               "Cloudiness":cloudiness,
                               "Wind Speed": wind_speed,
                               "Country": country,
                               "Date":date})



weatherdata_df
# Out:
#       City    Lat    Lng  Max Temp  Humidity  Cloudiness  Wind Speed Country  \
# 0    Adela  55.74  55.74     75.20        44          75       11.41      CA
# 1    Adela  22.08  22.08     80.60        88          90       14.99      US
# 2    Adela  69.22  69.22     57.20        41         100        3.36      GL
# 3    Adela  -0.74  -0.74     77.00        69          75       16.11      EC
# 4    Adela   5.41   5.41     82.40        94          40        4.70      MY
# ..     ...    ...    ...       ...       ...         ...         ...     ...
# 559  Adela  50.68  50.68     47.79        68          53        9.93      RU
# 560  Adela  18.22  18.22     87.80        58          40       16.11      AI
# 561  Adela   9.45   9.45     72.16        94          90        3.78      TD
# 562  Adela   3.82   3.82     73.71        97         100        2.06      ID
# 563  Adela  12.44  12.44     79.18        77         100        5.64      PH
#
#            Date
# 0    1595185129
# 1    1595185325
# 2    1595184808
# 3    1595185325
# 4    1595184656
# ..          ...
# 559  1595185122
# 560  1595184678
# 561  1595185122
# 562  1595185122
# 563  1595185122
#
# [564 rows x 9 columns]

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#  Get the indices of cities that have humidity over 100%.

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %%
# Extract relevant fields from the data frame


# Export the City_Data into a csv

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots

# %%
# Create Northern and Southern Hemisphere DataFrames

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
