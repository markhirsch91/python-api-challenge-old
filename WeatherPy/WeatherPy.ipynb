# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
from scipy.stats import linregress



# Import API key
from api_keys import weather_api_key


# Defininig Farenheit as units used in this project
units = "Imperial"


# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
#cities

base_url= "http://api.openweathermap.org/data/2.5/weather?"
units = "Imperial"
query_url = f"{base_url}appid={weather_api_key}&units={units}"
#query_url

print(len(cities))
cities
# Out:
# 616
# ['arraial do cabo',
#  'shingu',
#  'thompson',
#  'ngunguru',
#  'watertown',
#  'ribeira grande',
#  'botshabelo',
#  'hermanus',
#  'rikitea',
#  'punta arenas',
#  'longyearbyen',
#  'kurchum',
#  'roald',
#  'muros',
#  'kavaratti',
#  'cartagena del chaira',
#  'ossora',
#  'paveh',
#  'tuatapere',
#  'coihaique',
#  'georgetown',
#  'esperance',
#  'krivosheino',
#  'castro',
#  'umzimvubu',
#  'chapais',
#  'provideniya',
#  'tsihombe',
#  'talnakh',
#  'khatanga',
#  'auki',
#  'jamestown',
#  'ojinaga',
#  'bambous virieux',
#  'hambantota',
#  'tuktoyaktuk',
#  'constitucion',
#  'kamenskoye',
#  'kapaa',
#  'hobart',
#  'granville',
#  'magaria',
#  'blonduos',
#  'cape town',
#  'goderich',
#  'port alfred',
#  'tasiilaq',
#  'vaini',
#  'vila franca do campo',
#  'puerto ayora',
#  'kango',
#  'aden',
#  'east london',
#  'thunder bay',
#  'meyungs',
#  'dikson',
#  'avera',
#  'bredasdorp',
#  'bandarbeyla',
#  'saint-georges',
#  'yenagoa',
#  'busselton',
#  'vila',
#  'alta floresta',
#  'ponta do sol',
#  'mar del plata',
#  'cedral',
#  'buala',
#  'cherskiy',
#  'bluff',
#  'ibra',
#  'ladario',
#  'beringovskiy',
#  'richards bay',
#  'tocopilla',
#  'lebu',
#  'leningradskiy',
#  'guerrero negro',
#  'middletown',
#  'klaksvik',
#  'nome',
#  'porto novo',
#  'geraldton',
#  'altamira',
#  'newport',
#  'soyo',
#  'saint-philippe',
#  'ushuaia',
#  'xiangdong',
#  'denia',
#  'mataura',
#  'atuona',
#  'campbell river',
#  'codrington',
#  'barrow',
#  'chipinge',
#  'tecpan',
#  'pevek',
#  'bathsheba',
#  'tessalit',
#  'porbandar',
#  'new norfolk',
#  'antananarivo',
#  'dordrecht',
#  'mount isa',
#  'valparaiso',
#  'cabo san lucas',
#  'qaanaaq',
#  'sergeyevka',
#  'fairbanks',
#  'severo-kurilsk',
#  'dunedin',
#  'chokurdakh',
#  'avarua',
#  'spas-demensk',
#  'bengkulu',
#  'bereda',
#  'yoichi',
#  'foix',
#  'nova olinda do norte',
#  'olafsvik',
#  'butaritari',
#  'amderma',
#  'concepcion',
#  'rosetta',
#  'san luis',
#  'ilulissat',
#  'torbay',
#  'karakendzha',
#  'kavieng',
#  'nagod',
#  'lompoc',
#  'erzin',
#  'port hedland',
#  'shimoda',
#  'nampula',
#  'elko',
#  'sao filipe',
#  'souillac',
#  'taolanaro',
#  'waipawa',
#  'kruisfontein',
#  'albany',
#  'barentsburg',
#  'dzhusaly',
#  'hay river',
#  'oranjemund',
#  'illoqqortoormiut',
#  'faya',
#  'upernavik',
#  'kalmunai',
#  'namatanai',
#  'kirkuk',
#  'batticaloa',
#  'bismarck',
#  'yumen',
#  'carnarvon',
#  'rubiataba',
#  'salamiyah',
#  'bethel',
#  'molteno',
#  'pisco',
#  'victoria',
#  'flinders',
#  'mocuba',
#  'nikolskoye',
#  'vardo',
#  'sungaipenuh',
#  'kamsack',
#  'port elizabeth',
#  'menongue',
#  'axim',
#  'yar-sale',
#  'faanui',
#  'husavik',
#  'grindavik',
#  'zaranj',
#  'ivajlovgrad',
#  'sunrise manor',
#  'tromso',
#  'port moresby',
#  'port macquarie',
#  'poum',
#  'naryan-mar',
#  'zlobin',
#  'binjai',
#  'grand gaube',
#  'kodiak',
#  'laguna',
#  'hithadhoo',
#  'milkovo',
#  'norrtalje',
#  'katangli',
#  'tarudant',
#  'yellowknife',
#  'chuy',
#  'taua',
#  'orlik',
#  'horki',
#  'santa fe',
#  'raudeberg',
#  'turukhansk',
#  'mukhen',
#  'ketchikan',
#  'mys shmidta',
#  'siva',
#  'kawalu',
#  'itarema',
#  'kiama',
#  'tepelene',
#  'cidreira',
#  'lagoa',
#  'alofi',
#  'nuqui',
#  'jurm',
#  'lavrentiya',
#  'victor harbor',
#  'khash',
#  'lumphat',
#  'mount gambier',
#  'caohai',
#  'mackay',
#  'loviisa',
#  'laredo',
#  'kirakira',
#  'sioux lookout',
#  'qarqin',
#  'saint anthony',
#  'harwich',
#  'lunenburg',
#  'karratha',
#  'matamoros',
#  'hasanabad',
#  'padang',
#  'sambava',
#  'batemans bay',
#  'krutaya gorka',
#  'cockburn town',
#  'dingle',
#  'sao jose da coroa grande',
#  'paragominas',
#  'dalvik',
#  'yamada',
#  'moshenskoye',
#  'lexington',
#  'nanortalik',
#  'grootfontein',
#  'bulungu',
#  'gat',
#  'evensk',
#  'vao',
#  'tynda',
#  'churapcha',
#  'cap malheureux',
#  'kyaukse',
#  'sterlibashevo',
#  'virginia beach',
#  'margate',
#  'mirnyy',
#  'broken hill',
#  'dzerzhinsk',
#  'palabuhanratu',
#  'henties bay',
#  'japura',
#  'smithers',
#  'salta',
#  'hilo',
#  'contramaestre',
#  'ust-tsilma',
#  'kurilsk',
#  'kolomak',
#  'vestmannaeyjar',
#  'veraval',
#  'aklavik',
#  'hasaki',
#  'plettenberg bay',
#  'caravelas',
#  'mahebourg',
#  'nioki',
#  'crab hill',
#  'cocobeach',
#  'liwale',
#  'sompeta',
#  'conakry',
#  'astoria',
#  'san marino',
#  'attawapiskat',
#  'bonavista',
#  'khani',
#  'taltal',
#  'hoa binh',
#  'kemijarvi',
#  'saint george',
#  'shumskiy',
#  'hobyo',
#  'bela',
#  'murakami',
#  'jinchengjiang',
#  'antalaha',
#  'mahon',
#  'fukue',
#  'port hawkesbury',
#  'belushya guba',
#  'las vegas',
#  'kamenka',
#  'saskylakh',
#  'dongsheng',
#  'salinas',
#  'dafeng',
#  'grand river south east',
#  'teahupoo',
#  'ust-kuyga',
#  'wulanhaote',
#  'port lincoln',
#  'abu dhabi',
#  'namibe',
#  'anadyr',
#  'russell',
#  'saint-michel-des-saints',
#  'clyde river',
#  'san patricio',
#  'arrecife',
#  'charters towers',
#  'rio grande',
#  'matay',
#  'katobu',
#  'isangel',
#  'turkmenabat',
#  'quba',
#  'cacule',
#  'wilhelmsburg',
#  'sitka',
#  'banjar',
#  'sorvag',
#  'north bend',
#  'moengo',
#  'sentyabrskiy',
#  'bogorodskoye',
#  'mogadishu',
#  'barra do garcas',
#  'chimbote',
#  'gisborne',
#  'upata',
#  'mastic beach',
#  'sibolga',
#  'batouri',
#  'lasa',
#  'coos bay',
#  'kracheh',
#  'rafaela',
#  'silale',
#  'rocky mountain house',
#  'tiksi',
#  'acari',
#  'san carlos',
#  'culebra',
#  'pangnirtung',
#  'claveria',
#  'whitianga',
#  'surt',
#  'bloomsburg',
#  'kaeo',
#  'hamilton',
#  'belmonte',
#  'saldanha',
#  'la plata',
#  'cerro azul',
#  'kargopol',
#  'bend',
#  'urubicha',
#  'kaitangata',
#  'yulara',
#  'acajutla',
#  'sivaki',
#  'bagdarin',
#  'rorvik',
#  'mareeba',
#  'mildura',
#  'nadvoitsy',
#  'butembo',
#  'la palma',
#  'arlit',
#  'rio gallegos',
#  'luangwa',
#  'aliwal north',
#  'umm lajj',
#  'camacha',
#  'quinchia',
#  'lorengau',
#  'villamontes',
#  'borovsk',
#  'kem',
#  'bac lieu',
#  'astana',
#  'xichang',
#  'kudowa-zdroj',
#  'nantucket',
#  'bitung',
#  'jega',
#  'carepa',
#  'adrar',
#  'pacific grove',
#  'okha',
#  'la reforma',
#  'les cayes',
#  'nuuk',
#  'fort saint john',
#  'iqaluit',
#  'inhambane',
#  'santa ana',
#  'turbat',
#  'acapulco',
#  'acarau',
#  'villa carlos paz',
#  'general roca',
#  'quthing',
#  'semporna',
#  'qurunbaliyah',
#  'manakara',
#  'mahanje',
#  'mahajanga',
#  'fortuna',
#  'kindu',
#  'were ilu',
#  'mackenzie',
#  'barrhead',
#  'taybad',
#  'abalak',
#  'necochea',
#  'xudat',
#  'reconquista',
#  'havelock',
#  'hovd',
#  'sinnamary',
#  'cochrane',
#  'haines junction',
#  'milledgeville',
#  'panjab',
#  'la rioja',
#  'czersk',
#  'hluti',
#  'tarabuco',
#  'sabzevar',
#  'iroquois falls',
#  'swadlincote',
#  'baghdad',
#  'saint simons',
#  'keita',
#  'ati',
#  'lolua',
#  'san quintin',
#  'asuncion',
#  'vredendal',
#  'tambopata',
#  'lishui',
#  'morwell',
#  'sisimiut',
#  'tumannyy',
#  'sorland',
#  'magrath',
#  'morro bay',
#  'kadykchan',
#  'eldorado',
#  'samusu',
#  'taganak',
#  'yining',
#  'saleaula',
#  'sao felix do xingu',
#  'winona',
#  'portland',
#  'unai',
#  'nelson bay',
#  'qaqortoq',
#  'aquiraz',
#  'mayumba',
#  'brae',
#  'carballo',
#  'indramayu',
#  'mochudi',
#  'biak',
#  'narsaq',
#  'jalu',
#  'zheleznodorozhnyy',
#  'olga',
#  'deshna',
#  'ayagoz',
#  'puerto escondido',
#  'rockport',
#  'ures',
#  'thinadhoo',
#  'panama city',
#  'kaniama',
#  'hanmer springs',
#  'le port',
#  'taoudenni',
#  'broome',
#  'guadalupe y calvo',
#  'bodden town',
#  'paramonga',
#  'langsa',
#  'liapades',
#  'eskisehir',
#  'islamkot',
#  'horqueta',
#  'arawa',
#  'kathu',
#  'maniitsoq',
#  'santa rosalia',
#  'naliya',
#  'hami',
#  'santa cecilia',
#  'muli',
#  'takob',
#  'susaki',
#  'ondorhaan',
#  'mehamn',
#  'toulepleu',
#  'narrabri',
#  'ancud',
#  'sidney',
#  'hastings',
#  'komarov',
#  'wanning',
#  'manoel urbano',
#  'azimur',
#  'comodoro rivadavia',
#  'greymouth',
#  'santo angelo',
#  'quatre cocos',
#  'hokitika',
#  'camacari',
#  'pimentel',
#  'goure',
#  'takoradi',
#  'sakakah',
#  'nuh',
#  'obigarm',
#  'nizhneyansk',
#  'ponta delgada',
#  'blythe',
#  'lima',
#  'witrivier',
#  'tolbazy',
#  'utiroa',
#  'cap-aux-meules',
#  'mixtepec',
#  'dalnerechensk',
#  'eureka',
#  'steinbach',
#  'barkhan',
#  'changping',
#  'mrirt',
#  'halalo',
#  'huamachuco',
#  'ovalle',
#  'zemio',
#  'great yarmouth',
#  'usinsk',
#  'traverse city',
#  'deputatskiy',
#  'bayreuth',
#  'bergen',
#  'opuwo',
#  'tabiauea',
#  'ambon',
#  'gizo',
#  'hearst',
#  'candawaga',
#  'sao joao do piaui',
#  'roma',
#  'luganville',
#  'port blair',
#  'ostrovnoy',
#  'chongwe',
#  'conde',
#  'tilichiki',
#  'wakkanai',
#  'tarnogskiy gorodok',
#  'pecos',
#  'keetmanshoop',
#  'walvis bay',
#  'dryden',
#  'moyobamba',
#  'vieques',
#  'visnes',
#  'keffi',
#  'bonthe',
#  'bell ville',
#  'vizinga',
#  'murray bridge',
#  'terrace',
#  'solovetskiy',
#  'kargasok',
#  'san rafael',
#  'mana',
#  'shibetsu',
#  'martapura',
#  'baykit',
#  'ziro',
#  'dibaya',
#  'guanica',
#  'chabua',
#  'salinopolis',
#  'quelimane',
#  'zhigansk',
#  'galle',
#  'lac du bonnet',
#  'priboj',
#  'meulaboh',
#  'acuna',
#  'yangmei',
#  'neiafu',
#  'ternate',
#  'oskemen',
#  'bourbonnais',
#  'tura']

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
city_name_data = []
lat_list = []
lng_list = []
max_temp = []
humidity = []
cloudiness = []
wind_speed = []
country = []
date = []



print("Beginning Data Retrieval")
print("-----------------------------")

for city in cities:
    try:
        response = requests.get(f"{query_url}&q={city}").json()
        city_name_data.append(response["name"])
        lat_list.append(response["coord"]["lat"])
        lng_list.append(response["coord"]["lon"])
        max_temp.append(response["main"]["temp_max"])
        humidity.append(response["main"]["humidity"])
        cloudiness.append(response["clouds"]["all"])
        wind_speed.append(response["wind"]["speed"])
        country.append(response["sys"]["country"])
        date.append(response["dt"])
        city_print=(response["name"])
        print(f"Processing Record | {city_print}")
    except:
        print("No results, skipping.....")
    continue
    
print("-----------------------------")
print("Data Retrieval Complete")      
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record | Arraial do Cabo
# Processing Record | Shingū
# Processing Record | Thompson
# Processing Record | Ngunguru
# Processing Record | Watertown
# Processing Record | Ribeira Grande
# Processing Record | Botshabelo
# Processing Record | Hermanus
# Processing Record | Rikitea
# Processing Record | Punta Arenas
# Processing Record | Longyearbyen
# Processing Record | Kurchum
# Processing Record | Roald
# Processing Record | Muros
# Processing Record | Kavaratti
# Processing Record | Cartagena del Chairá
# Processing Record | Ossora
# Processing Record | Pāveh
# Processing Record | Tuatapere
# Processing Record | Coyhaique
# Processing Record | George Town
# Processing Record | Esperance
# Processing Record | Krivosheino
# Processing Record | Castro
# No results, skipping.....
# Processing Record | Chapais
# Processing Record | Provideniya
# No results, skipping.....
# Processing Record | Talnakh
# Processing Record | Khatanga
# Processing Record | Auki
# Processing Record | Jamestown
# Processing Record | Ojinaga
# Processing Record | Bambous Virieux
# Processing Record | Hambantota
# Processing Record | Tuktoyaktuk
# Processing Record | Constitución
# No results, skipping.....
# Processing Record | Kapaa
# Processing Record | Hobart
# Processing Record | Granville
# Processing Record | Magaria
# No results, skipping.....
# Processing Record | Cape Town
# Processing Record | Goderich
# Processing Record | Port Alfred
# Processing Record | Tasiilaq
# Processing Record | Vaini
# Processing Record | Vila Franca do Campo
# Processing Record | Puerto Ayora
# Processing Record | Kango
# Processing Record | Aden
# Processing Record | East London
# Processing Record | Thunder Bay
# No results, skipping.....
# Processing Record | Dikson
# Processing Record | Avera
# Processing Record | Bredasdorp
# Processing Record | Bandarbeyla
# Processing Record | St. George's
# Processing Record | Yenagoa
# Processing Record | Busselton
# Processing Record | Vila
# Processing Record | Alta Floresta
# Processing Record | Ponta do Sol
# Processing Record | Mar del Plata
# Processing Record | Cedral
# Processing Record | Buala
# Processing Record | Cherskiy
# Processing Record | Bluff
# Processing Record | Ibrā’
# Processing Record | Ladário
# Processing Record | Beringovskiy
# Processing Record | Richards Bay
# Processing Record | Tocopilla
# Processing Record | Lebu
# Processing Record | Leningradskiy
# Processing Record | Guerrero Negro
# Processing Record | Middletown
# Processing Record | Klaksvík
# Processing Record | Nome
# Processing Record | Porto-Novo
# Processing Record | Geraldton
# Processing Record | Altamira
# Processing Record | Newport
# Processing Record | Soyo
# Processing Record | Saint-Philippe
# Processing Record | Ushuaia
# No results, skipping.....
# Processing Record | Denia
# Processing Record | Mataura
# Processing Record | Atuona
# Processing Record | Campbell River
# Processing Record | Codrington
# Processing Record | Barrow
# Processing Record | Chipinge
# Processing Record | Tecpan
# Processing Record | Pevek
# Processing Record | Bathsheba
# Processing Record | Tessalit
# Processing Record | Porbandar
# Processing Record | New Norfolk
# Processing Record | Antananarivo
# Processing Record | Dordrecht
# Processing Record | Mount Isa
# Processing Record | Valparaíso
# Processing Record | Cabo San Lucas
# Processing Record | Qaanaaq
# Processing Record | Sergeevka
# Processing Record | Fairbanks
# Processing Record | Severo-Kuril'sk
# Processing Record | Dunedin
# Processing Record | Chokurdakh
# Processing Record | Avarua
# Processing Record | Spas-Demensk
# Processing Record | Bengkulu
# Processing Record | Bereda
# Processing Record | Yoichi
# Processing Record | Arrondissement de Foix
# Processing Record | Nova Olinda do Norte
# Processing Record | Olafsvik
# Processing Record | Butaritari
# No results, skipping.....
# Processing Record | Concepción
# Processing Record | Rosetta
# Processing Record | San Luis
# Processing Record | Ilulissat
# Processing Record | Torbay
# No results, skipping.....
# Processing Record | Kavieng
# Processing Record | Nāgod
# Processing Record | Lompoc
# Processing Record | Erzin
# Processing Record | Port Hedland
# Processing Record | Shimoda
# Processing Record | Nampula
# Processing Record | Elko
# Processing Record | São Filipe
# Processing Record | Souillac
# No results, skipping.....
# Processing Record | Waipawa
# Processing Record | Kruisfontein
# Processing Record | Albany
# No results, skipping.....
# No results, skipping.....
# Processing Record | Hay River
# Processing Record | Oranjemund
# No results, skipping.....
# Processing Record | Faya
# Processing Record | Upernavik
# Processing Record | Kalmunai
# Processing Record | Namatanai
# Processing Record | Kirkuk
# Processing Record | Batticaloa
# Processing Record | Bismarck
# Processing Record | Yumen
# Processing Record | Carnarvon
# Processing Record | Rubiataba
# Processing Record | Salamiyah
# Processing Record | Bethel
# Processing Record | Molteno
# Processing Record | Pisco
# Processing Record | Hong Kong
# Processing Record | Flinders
# Processing Record | Mocuba
# Processing Record | Nikolskoye
# Processing Record | Vardø
# Processing Record | Sungai Penuh
# Processing Record | Kamsack
# Processing Record | Port Elizabeth
# Processing Record | Menongue
# Processing Record | Esim
# Processing Record | Yar-Sale
# Processing Record | Faanui
# Processing Record | Husavik
# Processing Record | Grindavik
# Processing Record | Zaranj
# No results, skipping.....
# Processing Record | Sunrise Manor
# Processing Record | Tromsø
# Processing Record | Port Moresby
# Processing Record | Port Macquarie
# Processing Record | Poum
# Processing Record | Naryan-Mar
# Processing Record | Zlobin
# Processing Record | Binjai
# Processing Record | Grand Gaube
# Processing Record | Saint Paul Harbor
# Processing Record | Laguna
# Processing Record | Hithadhoo
# Processing Record | Mil'kovo
# Processing Record | Norrtälje
# Processing Record | Katangli
# No results, skipping.....
# Processing Record | Yellowknife
# Processing Record | Chui
# Processing Record | Tauá
# Processing Record | Orlik
# Processing Record | Horki
# Processing Record | Santa Fe
# Processing Record | Raudeberg
# Processing Record | Turukhansk
# Processing Record | Mukhen
# Processing Record | Ketchikan
# No results, skipping.....
# Processing Record | Sīwah
# Processing Record | Kawalu
# Processing Record | Itarema
# Processing Record | Kiama
# Processing Record | Tepelenë
# Processing Record | Cidreira
# Processing Record | Lagoa
# Processing Record | Alofi
# Processing Record | Nuquí
# Processing Record | Jurm
# Processing Record | Lavrentiya
# Processing Record | Victor Harbor
# Processing Record | Khāsh
# Processing Record | Lumphat
# Processing Record | Mount Gambier
# Processing Record | Caohai
# Processing Record | Mackay
# Processing Record | Loviisa
# Processing Record | Laredo
# Processing Record | Kirakira
# Processing Record | Sioux Lookout
# Processing Record | Qarqīn
# Processing Record | Saint Anthony
# Processing Record | Harwich
# Processing Record | Lunenburg
# Processing Record | Karratha
# Processing Record | Matamoros
# Processing Record | Ḩasanābād
# Processing Record | Padang
# Processing Record | Sambava
# Processing Record | Batemans Bay
# Processing Record | Krutaya Gorka
# Processing Record | Cockburn Town
# Processing Record | Dingle
# Processing Record | São José da Coroa Grande
# Processing Record | Paragominas
# Processing Record | Dalvik
# Processing Record | Yamada
# Processing Record | Moshenskoye
# Processing Record | Lexington
# Processing Record | Nanortalik
# Processing Record | Grootfontein
# Processing Record | Bulungu
# Processing Record | Kiryat Gat
# Processing Record | Evensk
# Processing Record | Vao
# Processing Record | Tynda
# Processing Record | Churapcha
# Processing Record | Cap Malheureux
# Processing Record | Kyaukse
# Processing Record | Sterlibashevo
# Processing Record | Virginia Beach
# Processing Record | Margate
# Processing Record | Mirny
# Processing Record | Broken Hill
# Processing Record | Dzerzhinsk
# No results, skipping.....
# Processing Record | Henties Bay
# Processing Record | Japura
# Processing Record | Smithers
# Processing Record | Salta
# Processing Record | Hilo
# Processing Record | Contramaestre
# Processing Record | Ust-Tsilma
# Processing Record | Kuril'sk
# Processing Record | Kolomak
# Processing Record | Vestmannaeyjar
# Processing Record | Verāval
# Processing Record | Aklavik
# Processing Record | Hasaki
# Processing Record | Plettenberg Bay
# Processing Record | Caravelas
# Processing Record | Mahébourg
# Processing Record | Nioki
# No results, skipping.....
# Processing Record | Cocobeach
# Processing Record | Liwale
# Processing Record | Sompeta
# Processing Record | Conakry
# Processing Record | Astoria
# Processing Record | San Marino
# No results, skipping.....
# Processing Record | Bonavista
# Processing Record | Khani
# Processing Record | Taltal
# Processing Record | Hoa Binh
# Processing Record | Kemijärvi
# Processing Record | Saint George
# Processing Record | Shumskiy
# Processing Record | Hobyo
# Processing Record | Bela
# Processing Record | Murakami
# No results, skipping.....
# Processing Record | Antalaha
# Processing Record | Mahon
# Processing Record | Fukuechō
# Processing Record | Port Hawkesbury
# No results, skipping.....
# Processing Record | Las Vegas
# Processing Record | Kamenka
# Processing Record | Saskylakh
# Processing Record | Dongsheng
# Processing Record | Salinas
# Processing Record | Dafeng
# No results, skipping.....
# Processing Record | Teahupoo
# Processing Record | Ust-Kuyga
# No results, skipping.....
# Processing Record | Port Lincoln
# Processing Record | Abu Dhabi
# Processing Record | Mossamedes
# Processing Record | Anadyr
# Processing Record | Russell
# Processing Record | Saint-Michel-des-Saints
# Processing Record | Clyde River
# Processing Record | San Patricio
# Processing Record | Arrecife
# Processing Record | Charters Towers
# Processing Record | Rio Grande
# Processing Record | Maţāy
# Processing Record | Katobu
# Processing Record | Isangel
# Processing Record | Turkmenabat
# Processing Record | Quba
# Processing Record | Caculé
# Processing Record | Wilhelmsburg
# Processing Record | Sitka
# Processing Record | Banjar
# No results, skipping.....
# Processing Record | North Bend
# Processing Record | Moengo
# No results, skipping.....
# Processing Record | Bogorodskoye
# Processing Record | Mogadishu
# Processing Record | Barra do Garças
# Processing Record | Chimbote
# Processing Record | Gisborne
# Processing Record | Upata
# Processing Record | Mastic Beach
# Processing Record | Sibolga
# Processing Record | Batouri
# Processing Record | Laas
# Processing Record | Coos Bay
# No results, skipping.....
# Processing Record | Rafaela
# Processing Record | Šilalė
# Processing Record | Rocky Mountain House
# Processing Record | Tiksi
# Processing Record | Acarí
# Processing Record | San Carlos
# Processing Record | Culebra
# Processing Record | Pangnirtung
# Processing Record | Claveria
# Processing Record | Whitianga
# Processing Record | Sirte
# Processing Record | Bloomsburg
# Processing Record | Kaeo
# Processing Record | Hamilton
# Processing Record | Belmonte
# Processing Record | Saldanha
# Processing Record | La Plata
# Processing Record | Cerro Azul
# Processing Record | Kargopol'
# Processing Record | Bend
# Processing Record | Urubichá
# Processing Record | Kaitangata
# Processing Record | Yulara
# Processing Record | Acajutla
# Processing Record | Sivaki
# Processing Record | Bagdarin
# Processing Record | Rørvik
# Processing Record | Mareeba
# Processing Record | Mildura
# Processing Record | Nadvoitsy
# Processing Record | Butembo
# Processing Record | La Palma
# Processing Record | Arlit
# Processing Record | Río Gallegos
# Processing Record | Luangwa
# Processing Record | Aliwal North
# Processing Record | Umluj
# Processing Record | Camacha
# Processing Record | Quinchía
# Processing Record | Lorengau
# Processing Record | Villamontes
# Processing Record | Borovsk
# Processing Record | Kem'
# Processing Record | Bac Lieu
# Processing Record | Nur-Sultan
# Processing Record | Xichang
# Processing Record | Kudowa-Zdrój
# Processing Record | Nantucket
# Processing Record | Bitung
# Processing Record | Jega
# Processing Record | Carepa
# Processing Record | Adrar
# Processing Record | Pacific Grove
# Processing Record | Okha
# Processing Record | La Reforma
# Processing Record | Les Cayes
# Processing Record | Nuuk
# No results, skipping.....
# Processing Record | Iqaluit
# Processing Record | Inhambane
# Processing Record | Santa Ana
# Processing Record | Turbat
# Processing Record | Acapulco de Juárez
# Processing Record | Acaraú
# Processing Record | Villa Carlos Paz
# Processing Record | General Roca
# Processing Record | Quthing
# Processing Record | Semporna
# No results, skipping.....
# Processing Record | Manakara
# Processing Record | Mahanje
# Processing Record | Mahajanga
# Processing Record | Fortuna
# Processing Record | Kindu
# Processing Record | Were Īlu
# Processing Record | Mackenzie
# Processing Record | Barrhead
# Processing Record | Tāybād
# Processing Record | Abalak
# Processing Record | Necochea
# Processing Record | Xudat
# Processing Record | Reconquista
# Processing Record | Havelock
# Processing Record | Khovd
# Processing Record | Sinnamary
# Processing Record | Cochrane
# Processing Record | Haines Junction
# Processing Record | Milledgeville
# Processing Record | Panjāb
# Processing Record | La Rioja
# Processing Record | Czersk
# Processing Record | Hluti
# Processing Record | Tarabuco
# Processing Record | Sabzawār
# Processing Record | Iroquois Falls
# Processing Record | Swadlincote
# Processing Record | Baghdad
# Processing Record | Saint Simons
# Processing Record | Keïta
# Processing Record | Ati
# No results, skipping.....
# Processing Record | San Quintín
# Processing Record | Asunción
# Processing Record | Vredendal
# Processing Record | Tambopata
# Processing Record | Lishui
# Processing Record | Morwell
# Processing Record | Sisimiut
# No results, skipping.....
# Processing Record | Sørland
# Processing Record | Magrath
# Processing Record | Morro Bay
# No results, skipping.....
# Processing Record | Eldorado
# No results, skipping.....
# Processing Record | Taganak
# Processing Record | Yining
# No results, skipping.....
# Processing Record | São Félix do Xingu
# Processing Record | Winona
# Processing Record | Portland
# Processing Record | Unaí
# Processing Record | Nelson Bay
# Processing Record | Qaqortoq
# Processing Record | Aquiraz
# Processing Record | Mayumba
# Processing Record | Brae
# Processing Record | Carballo
# Processing Record | Indramayu
# Processing Record | Mochudi
# Processing Record | Biak
# Processing Record | Narsaq
# Processing Record | Jalu
# Processing Record | Zheleznodorozhnyy
# Processing Record | Ol'ga
# No results, skipping.....
# Processing Record | Ayagoz
# Processing Record | Puerto Escondido
# Processing Record | Rockport
# Processing Record | Ures
# Processing Record | Thinadhoo
# Processing Record | Panama City
# Processing Record | Kaniama
# Processing Record | Hanmer Springs
# Processing Record | Le Port
# Processing Record | Taoudenni
# Processing Record | Broome
# Processing Record | Guadalupe y Calvo
# Processing Record | Bodden Town
# Processing Record | Paramonga
# Processing Record | Langsa
# No results, skipping.....
# Processing Record | Eskişehir
# Processing Record | Islamkot
# Processing Record | Horqueta
# Processing Record | Arawa
# Processing Record | Kathu
# Processing Record | Maniitsoq
# Processing Record | Santa Rosalía
# Processing Record | Naliya
# Processing Record | Kumul
# Processing Record | Santa Cecília
# Processing Record | Muli
# No results, skipping.....
# Processing Record | Susaki
# No results, skipping.....
# Processing Record | Mehamn
# No results, skipping.....
# Processing Record | Narrabri
# Processing Record | Ancud
# Processing Record | Sydney
# Processing Record | Hastings
# Processing Record | Komárov
# Processing Record | Wanning
# Processing Record | Manoel Urbano
# No results, skipping.....
# Processing Record | Comodoro Rivadavia
# Processing Record | Greymouth
# Processing Record | Santo Ângelo
# Processing Record | Quatre Cocos
# Processing Record | Hokitika
# Processing Record | Camaçari
# Processing Record | Pimentel
# Processing Record | Gouré
# Processing Record | Takoradze
# Processing Record | Sakakah
# Processing Record | Nūh
# Processing Record | Obigarm
# No results, skipping.....
# Processing Record | Ponta Delgada
# Processing Record | Blythe
# Processing Record | Lima
# No results, skipping.....
# Processing Record | Tolbazy
# No results, skipping.....
# Processing Record | Cap-aux-Meules
# No results, skipping.....
# Processing Record | Dalnerechensk
# Processing Record | Eureka
# Processing Record | Steinbach am Taunus
# Processing Record | Barkhan
# Processing Record | Changping
# No results, skipping.....
# No results, skipping.....
# Processing Record | Huamachuco
# Processing Record | Ovalle
# Processing Record | Zemio
# Processing Record | Great Yarmouth
# Processing Record | Usinsk
# Processing Record | Traverse City
# Processing Record | Deputatsky
# Processing Record | Bayreuth
# Processing Record | Bergen
# Processing Record | Opuwo
# No results, skipping.....
# Processing Record | Ambon City
# Processing Record | Gizo Government Station
# Processing Record | Hearst
# No results, skipping.....
# Processing Record | São João do Piauí
# Processing Record | Rome
# Processing Record | Luganville
# Processing Record | Port Blair
# Processing Record | Ostrovnoy
# Processing Record | Chongwe
# Processing Record | Conde
# Processing Record | Tilichiki
# Processing Record | Wakkanai
# Processing Record | Tarnogskiy Gorodok
# Processing Record | Pecos
# Processing Record | Keetmanshoop
# Processing Record | Walvis Bay
# Processing Record | Dryden
# Processing Record | Moyobamba
# Processing Record | Vieques
# Processing Record | Visnes
# Processing Record | Keffi
# Processing Record | Bonthe
# Processing Record | Bell Ville
# Processing Record | Vizinga
# Processing Record | Murray Bridge
# Processing Record | Terrace
# No results, skipping.....
# Processing Record | Kargasok
# Processing Record | San Rafael
# Processing Record | Mana
# Processing Record | Shibetsu
# Processing Record | Martapura
# Processing Record | Baykit
# Processing Record | Ziro
# No results, skipping.....
# Processing Record | Guánica
# Processing Record | Chābua
# Processing Record | Salinópolis
# Processing Record | Quelimane
# Processing Record | Zhigansk
# Processing Record | Galle
# Processing Record | Lac du Bonnet
# Processing Record | Priboj
# Processing Record | Meulaboh
# No results, skipping.....
# Processing Record | Yangmei
# Processing Record | Neiafu
# Processing Record | Ternate
# Processing Record | Oskemen
# Processing Record | Bourbonnais
# Processing Record | Tura
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# weatherdata_df = pd.DataFrame({"City":city_name_data, 
#                                "Lat": lat_list,
#                                "Lng": lng_list,
#                                "Max Temp": max_temp,
#                                "Humidity": humidity,
#                                "Cloudiness":cloudiness,
#                                "Wind Speed": wind_speed,
#                                "Country": country,
#                                "Date":date})
# weatherdata_df


weather_dictionary_list = ({"City":city_name_data, 
                               "Lat": lat_list,
                               "Lng": lng_list,
                               "Max Temp": max_temp,
                               "Humidity": humidity,
                               "Cloudiness":cloudiness,
                               "Wind Speed": wind_speed,
                               "Country": country,
                               "Date":date})

weather_life_df = pd.DataFrame(weather_dictionary_list)


weather_life_df
# Out:
#                 City    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0    Arraial do Cabo -22.97  -42.03     70.95        85           0
# 1             Shingū  33.73  135.98     78.80        94          75
# 2           Thompson  55.74  -97.86     75.20        44          75
# 3           Ngunguru -35.62  174.50     61.00         3          41
# 4          Watertown  42.37  -71.18     88.00        55           1
# ..               ...    ...     ...       ...       ...         ...
# 562           Neiafu -18.65 -173.98     73.40        83          75
# 563          Ternate   0.80  127.40     81.81        75          41
# 564          Oskemen  49.96   82.61     57.20        87          40
# 565      Bourbonnais  41.14  -87.88     82.40        61           1
# 566             Tura  25.52   90.22     73.81        99         100
#
#      Wind Speed Country        Date
# 0         22.59      BR  1595203065
# 1          3.36      JP  1595203065
# 2          4.70      CA  1595202939
# 3          3.00      NZ  1595203065
# 4         12.75      US  1595203027
# ..          ...     ...         ...
# 562       14.99      TO  1595203149
# 563        3.02      ID  1595203149
# 564        2.24      KZ  1595203149
# 565        8.05      US  1595203085
# 566        7.56      IN  1595203149
#
# [567 rows x 9 columns]

# %%
weather_life_df.to_csv(index=False)
# Out:
# "City,Lat,Lng,Max Temp,Humidity,Cloudiness,Wind Speed,Country,Date\r\nArraial do Cabo,-22.97,-42.03,70.95,85,0,22.59,BR,1595203065\r\nShingū,33.73,135.98,78.8,94,75,3.36,JP,1595203065\r\nThompson,55.74,-97.86,75.2,44,75,4.7,CA,1595202939\r\nNgunguru,-35.62,174.5,61.0,3,41,3.0,NZ,1595203065\r\nWatertown,42.37,-71.18,88.0,55,1,12.75,US,1595203027\r\nRibeira Grande,38.52,-28.7,69.19,76,72,3.53,PT,1595203065\r\nBotshabelo,-29.27,26.71,26.6,58,0,2.24,ZA,1595203065\r\nHermanus,-34.42,19.23,53.01,95,3,1.99,ZA,1595203066\r\nRikitea,-23.12,-134.97,68.68,62,45,11.03,PF,1595202890\r\nPunta Arenas,-53.15,-70.92,35.01,69,63,5.99,CL,1595202950\r\nLongyearbyen,78.22,15.64,44.6,87,75,12.75,SJ,1595203066\r\nKurchum,48.57,83.65,72.34,52,52,2.64,KZ,1595203066\r\nRoald,62.58,6.13,53.6,81,9,8.05,NO,1595203066\r\nMuros,42.78,-9.06,66.99,82,1,11.99,ES,1595203066\r\nKavaratti,10.57,72.64,81.32,79,100,13.78,IN,1595203067\r\nCartagena del Chairá,1.33,-74.84,73.26,94,62,2.19,CO,1595203067\r\nOssora,59.24,163.07,52.7,90,97,17.09,RU,1595203067\r\nPāveh,35.04,46.36,66.43,24,0,2.46,IR,1595203067\r\nTuatapere,-46.13,167.68,39.0,83,96,3.0,NZ,1595203067\r\nCoyhaique,-45.58,-72.07,33.8,100,90,4.7,CL,1595203067\r\nGeorge Town,5.41,100.34,78.8,94,20,2.24,MY,1595203068\r\nEsperance,-33.87,121.9,50.0,76,90,3.36,AU,1595203068\r\nKrivosheino,57.34,83.93,65.61,97,94,4.54,RU,1595203068\r\nCastro,-24.79,-50.01,57.25,91,18,3.8,BR,1595203068\r\nChapais,49.78,-74.85,75.2,73,90,8.05,CA,1595203068\r\nProvideniya,64.38,-173.3,53.6,71,75,13.42,RU,1595203068\r\nTalnakh,69.49,88.4,50.0,76,87,15.66,RU,1595203069\r\nKhatanga,71.97,102.5,51.78,77,98,2.68,RU,1595203069\r\nAuki,-8.77,160.7,85.35,66,10,3.6,SB,1595203069\r\nJamestown,42.1,-79.24,73.0,100,90,13.87,US,1595202922\r\nOjinaga,29.57,-104.42,100.4,21,1,5.82,MX,1595203069\r\nBambous Virieux,-20.34,57.76,66.99,88,40,5.82,MU,1595203069\r\nHambantota,6.12,81.12,79.14,82,88,5.93,LK,1595203069\r\nTuktoyaktuk,69.45,-133.04,46.4,75,40,4.7,CA,1595203070\r\nConstitución,-35.33,-72.42,52.83,87,66,7.9,CL,1595203070\r\nKapaa,22.08,-159.32,84.2,74,75,16.11,US,1595203070\r\nHobart,-42.88,147.33,46.4,70,40,13.87,AU,1595202811\r\nGranville,-33.83,151.02,59.0,43,0,16.11,AU,1595203070\r\nMagaria,13.0,8.91,83.34,56,25,14.29,NE,1595203070\r\nCape Town,-33.93,18.42,59.0,93,75,9.17,ZA,1595203071\r\nGoderich,43.75,-81.72,77.0,85,81,15.7,CA,1595203053\r\nPort Alfred,-33.59,26.89,60.26,62,0,6.55,ZA,1595203071\r\nTasiilaq,65.61,-37.64,48.2,81,0,5.82,GL,1595203071\r\nVaini,-21.2,-175.2,68.0,100,90,9.17,TO,1595203071\r\nVila Franca do Campo,37.72,-25.43,69.8,68,75,5.82,PT,1595203071\r\nPuerto Ayora,-0.74,-90.35,70.0,90,92,5.99,EC,1595203071\r\nKango,0.19,10.1,74.05,86,94,3.13,GA,1595203071\r\nAden,12.78,45.04,85.73,71,40,19.26,YE,1595202779\r\nEast London,-33.02,27.91,59.54,52,0,6.15,ZA,1595203072\r\nThunder Bay,48.4,-89.32,66.2,68,75,21.92,CA,1595203072\r\nDikson,73.51,80.55,41.09,95,100,10.96,RU,1595203072\r\nAvera,33.19,-82.53,95.0,41,1,5.82,US,1595203072\r\nBredasdorp,-34.53,20.04,57.2,93,6,1.12,ZA,1595203072\r\nBandarbeyla,9.49,50.81,79.54,63,76,23.0,SO,1595203073\r\nSt. George's,12.06,-61.75,84.2,74,20,14.99,GD,1595203073\r\nYenagoa,4.92,6.26,73.69,96,100,1.28,NG,1595203073\r\nBusselton,-33.65,115.33,48.0,79,36,7.72,AU,1595203073\r\nVila,42.03,-8.16,66.99,86,0,3.42,PT,1595203073\r\nAlta Floresta,-9.88,-56.09,77.23,42,64,4.25,BR,1595203073\r\nPonta do Sol,32.67,-17.1,73.4,60,20,13.87,PT,1595203073\r\nMar del Plata,-38.0,-57.56,52.0,93,75,12.75,AR,1595202834\r\nCedral,23.8,-100.73,80.62,26,47,17.49,MX,1595203074\r\nBuala,-8.14,159.59,83.86,71,54,5.26,SB,1595203074\r\nCherskiy,68.75,161.3,72.34,40,0,4.81,RU,1595203074\r\nBluff,-46.6,168.33,39.0,83,75,3.0,NZ,1595203074\r\nIbrā’,22.69,58.53,82.04,76,79,5.77,OM,1595203074\r\nLadário,-19.0,-57.6,77.22,43,0,2.73,BR,1595203074\r\nBeringovskiy,63.05,179.32,45.12,76,60,15.17,RU,1595203074\r\nRichards Bay,-28.78,32.04,57.63,84,0,5.06,ZA,1595203074\r\nTocopilla,-22.09,-70.2,60.12,66,92,8.32,CL,1595203075\r\nLeb ...

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#  Get the indices of cities that have humidity over 100%.

#weather_life_df.drop(weather_life_df['Humidity']>100)

# weather_life_df.filter


#cleaned_weather_life_df= weather_life_df.loc[(weather_life_df['Humidity'] > 100)]


# weather_life_df.filter(weather_life_df['Humidity']>50)

weather_life_df
# Out:
#                 City    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0    Arraial do Cabo -22.97  -42.03     70.95        85           0
# 1             Shingū  33.73  135.98     78.80        94          75
# 2           Thompson  55.74  -97.86     75.20        44          75
# 3           Ngunguru -35.62  174.50     61.00         3          41
# 4          Watertown  42.37  -71.18     88.00        55           1
# ..               ...    ...     ...       ...       ...         ...
# 562           Neiafu -18.65 -173.98     73.40        83          75
# 563          Ternate   0.80  127.40     81.81        75          41
# 564          Oskemen  49.96   82.61     57.20        87          40
# 565      Bourbonnais  41.14  -87.88     82.40        61           1
# 566             Tura  25.52   90.22     73.81        99         100
#
#      Wind Speed Country        Date
# 0         22.59      BR  1595203065
# 1          3.36      JP  1595203065
# 2          4.70      CA  1595202939
# 3          3.00      NZ  1595203065
# 4         12.75      US  1595203027
# ..          ...     ...         ...
# 562       14.99      TO  1595203149
# 563        3.02      ID  1595203149
# 564        2.24      KZ  1595203149
# 565        8.05      US  1595203085
# 566        7.56      IN  1595203149
#
# [567 rows x 9 columns]

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %%
# Extract relevant fields from the data frame


# Export the City_Data into a csv

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots

# %%
# Create Northern and Southern Hemisphere DataFrames

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
